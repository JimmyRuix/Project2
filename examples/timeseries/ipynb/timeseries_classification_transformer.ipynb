# %% [markdown]
# # Timeseries classification with a Transformer model
#
# **Author:** [Theodoros Ntakouris](https://github.com/ntakouris)<br>
# **Date created:** 2021/06/25<br>
# **Last modified:** 2021/08/05<br>
# **Description:** This notebook demonstrates how to do timeseries classification using a Transformer model.

# %% [markdown]
# ## Introduction
#
# This is the Transformer architecture from
# [Attention Is All You Need](https://arxiv.org/abs/1706.03762),
# applied to timeseries instead of natural language.
#
# This example requires TensorFlow 2.4 or higher.
#
# ## Load the dataset
#
# We are going to use the same dataset and preprocessing as the
# [TimeSeries Classification from Scratch](https://keras.io/examples/timeseries/timeseries_classification_from_scratch)
# example.

# %%
import numpy as np
import keras
from keras import layers


def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

n_classes = len(np.unique(y_train))

idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build the model
#
# Our model processes a tensor of shape `(batch size, sequence length, features)`,
# where `sequence length` is the number of time steps and `features` is each input
# timeseries.
#
# You can replace your classification RNN layers with this one: the
# inputs are fully compatible!
#
# We include residual connections, layer normalization, and dropout.
# The resulting layer can be stacked multiple times.
#
# The projection layers are implemented through `keras.layers.Conv1D`.

# %%
# This implementation applies Layer Normalization before the residual connection
# to improve training stability by producing better-behaved gradients and often
# eliminating the need for learning rate warm-up.


def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %% [markdown]
# The main part of our model is now complete. We can stack multiple of those
# `transformer_encoder` blocks and we can also proceed to add the final
# Multi-Layer Perceptron classification head. Apart from a stack of `Dense`
# layers, we need to reduce the output tensor of the `TransformerEncoder` part of
# our model down to a vector of features for each data point in the current
# batch. A common way to achieve this is to use a pooling layer. For
# this example, a `GlobalAveragePooling1D` layer is sufficient.

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# ## Train and evaluate

# %%
input_shape = x_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=2,
    mlp_units=[128],
    mlp_dropout=0.3,
    dropout=0.3,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=30, restore_best_weights=True)]

model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=150,
    batch_size=32,
    callbacks=callbacks,
)

model.evaluate(x_test, y_test, verbose=1)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 500, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 500, 1)    │      7,169 │ input_layer_5[0]… │
# │ (MultiHeadAttentio… │                   │            │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_66          │ (None, 500, 1)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ dropout_66[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_40 (Add)        │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_40 (Conv1D)  │ (None, 500, 4)    │          8 │ add_40[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_67          │ (None, 500, 4)    │          0 │ conv1d_40[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_41 (Conv1D)  │ (None, 500, 1)    │          5 │ dropout_67[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ conv1d_41[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_41 (Add)        │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_40[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 500, 1)    │      7,169 │ add_41[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_41[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_69          │ (None, 500, 1)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ dropout_69[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_42 (Add)        │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_41[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_42 (Conv1D)  │ (None, 500, 4)    │          8 │ add_42[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_70          │ (None, 500, 4)    │          0 │ conv1d_42[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_43 (Conv1D)  │ (None, 500, 1)    │          5 │ dropout_70[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ conv1d_43[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_42[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1)         │          0 │ add_43[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 128)       │        256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_71          │ (None, 128)       │          0 │ dense_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 2)         │        258 │ dropout_71[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,886 (58.15 KB)
#  Trainable params: 14,886 (58.15 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5090 - val_loss: 0.6939 - val_sparse_categorical_accuracy: 0.4854
# Epoch 2/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6943 - val_sparse_categorical_accuracy: 0.4854
# Epoch 3/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6947 - val_sparse_categorical_accuracy: 0.4854
# Epoch 4/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 88ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6946 - val_sparse_categorical_accuracy: 0.4854
# Epoch 5/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 89ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6949 - val_sparse_categorical_accuracy: 0.4854
# Epoch 6/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6951 - val_sparse_categorical_accuracy: 0.4854
# Epoch 7/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6950 - val_sparse_categorical_accuracy: 0.4854
# Epoch 8/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6949 - val_sparse_categorical_accuracy: 0.4854
# Epoch 9/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6950 - val_sparse_categorical_accuracy: 0.4854
# Epoch 10/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6951 - val_sparse_categorical_accuracy: 0.4854
# Epoch 11/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6947 - val_sparse_categorical_accuracy: 0.4854
# Epoch 12/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6948 - val_sparse_categorical_accuracy: 0.4854
# Epoch 13/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6953 - val_sparse_categorical_accuracy: 0.4854
# Epoch 14/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6952 - val_sparse_categorical_accuracy: 0.4854
# Epoch 15/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6955 - val_sparse_categorical_accuracy: 0.4854
# Epoch 16/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6949 - val_sparse_categorical_accuracy: 0.4854
# Epoch 17/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6946 - val_sparse_categorical_accuracy: 0.4854
# Epoch 18/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6949 - val_sparse_categorical_accuracy: 0.4854
# Epoch 19/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6998 - val_sparse_categorical_accuracy: 0.4854
# Epoch 20/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6946 - val_sparse_categorical_accuracy: 0.4854
# Epoch 21/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6955 - val_sparse_categorical_accuracy: 0.4854
# Epoch 22/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6946 - val_sparse_categorical_accuracy: 0.4854
# Epoch 23/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6949 - val_sparse_categorical_accuracy: 0.4854
# Epoch 24/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6946 - val_sparse_categorical_accuracy: 0.4854
# Epoch 25/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6948 - val_sparse_categorical_accuracy: 0.4854
# Epoch 26/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6923 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6950 - val_sparse_categorical_accuracy: 0.4854
# Epoch 27/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6922 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6952 - val_sparse_categorical_accuracy: 0.4854
# Epoch 28/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6952 - val_sparse_categorical_accuracy: 0.4854
# Epoch 29/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6923 - sparse_categorical_accuracy: 0.5198 - val_loss: 0.6943 - val_sparse_categorical_accuracy: 0.4854
# Epoch 30/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5191 - val_loss: 0.6951 - val_sparse_categorical_accuracy: 0.4854
# Epoch 31/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5194 - val_loss: 0.6949 - val_sparse_categorical_accuracy: 0.4854
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5159
# [0.6927064657211304, 0.5159090757369995]

# %% [markdown]
# ## Conclusions
#
# In about 110-120 epochs (25s each on Colab), the model reaches a training
# accuracy of ~0.95, validation accuracy of ~84 and a testing
# accuracy of ~85, without hyperparameter tuning. And that is for a model
# with less than 100k parameters. Of course, parameter count and accuracy could be
# improved by a hyperparameter search and a more sophisticated learning rate
# schedule, or a different optimizer.
